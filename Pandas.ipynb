# %% [markdown]
# # Working with padas

# %%
import pandas as pd
import numpy as np

# %%
ab={
    "ID":[1,2,3,4,5],
    "Name":["sagaar","sachin","pooja","poonam","seema"],
    "City":["pune","mumbai","satara","karad","latur"],
    "Salary":[2000,3000,4000,5000,3000]
}
print(ab)
# Out:
# {'ID': [1, 2, 3, 4, 5], 'Name': ['sagaar', 'sachin', 'pooja', 'poonam', 'seema'], 'City': ['pune', 'mumbai', 'satara', 'karad', 'latur'], 'Salary': [2000, 3000, 4000, 5000, 3000]}

# %%
data=pd.DataFrame(ab)
data
# Out:
#    ID    Name    City  Salary
# 0   1  sagaar    pune    2000
# 1   2  sachin  mumbai    3000
# 2   3   pooja  satara    4000
# 3   4  poonam   karad    5000
# 4   5   seema   latur    3000

# %%
data.to_csv("dictionaries.csv",index=False)
data3=pd.read_csv("dictionaries.csv")
data3
# Out:
#    ID    Name    City  Salary
# 0   1  sagaar    pune    2000
# 1   2  sachin  mumbai    3000
# 2   3   pooja  satara    4000
# 3   4  poonam   karad    5000
# 4   5   seema   latur    3000

# %%
dataset=pd.read_csv(r"C:\Users\Parimal\Downloads\Houseprice_by_City.csv")

# %%
dataset
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                  City  LONGITUDE   LATITUDE  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29451 entries, 0 to 29450
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   POSTED_BY              29451 non-null  object
#  1   UNDER_CONSTRUCTION     29451 non-null  int64
#  2   RERA                   29451 non-null  int64
#  3   BHK_NO.                29451 non-null  int64
#  4   BHK_OR_RK              29451 non-null  object
#  5   SQUARE_FT              29451 non-null  float64
#  6   READY_TO_MOVE          29451 non-null  int64
#  7   RESALE                 29451 non-null  int64
#  8   City                   29442 non-null  object
#  9   LONGITUDE              29451 non-null  float64
#  10  LATITUDE               29451 non-null  float64
#  11  TARGET(PRICE_IN_LACS)  29451 non-null  float64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 2.7+ MB

# %%
dataset.head(100)
# Out:
#    POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0      Owner                   0     0        2       BHK  1300.236407
# 1     Dealer                   0     0        2       BHK  1275.000000
# 2      Owner                   0     0        2       BHK   933.159722
# 3      Owner                   0     1        2       BHK   929.921143
# 4     Dealer                   1     0        2       BHK   999.009247
# ..       ...                 ...   ...      ...       ...          ...
# 95    Dealer                   0     0        3       BHK  1200.082764
# 96    Dealer                   0     0        2       BHK  1584.283904
# 97     Owner                   0     0        2       BHK   900.000000
# 98    Dealer                   0     1        2       BHK  1193.440032
# 99     Owner                   0     0        2       BHK  1487.357462
#
#     READY_TO_MOVE  RESALE         City  LONGITUDE   LATITUDE  \
# ...

# %%
dataset.tail(10)
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 29441     Owner                   0     0        3       BHK  1500.375094
# 29442    Dealer                   0     0        3       BHK  1554.968123
# 29443    Dealer                   0     1        3       BHK  1161.194975
# 29444    Dealer                   1     1        1       BHK   752.049334
# 29445     Owner                   0     0        2       BHK  1062.134891
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                  City  LONGITUDE   LATITUDE  \
# 29441              1       1             Faridabad  28.320000  77.289381
# ...

# %%
dataset.describe()
# Out:
#        UNDER_CONSTRUCTION          RERA       BHK_NO.     SQUARE_FT  \
# count        29451.000000  29451.000000  29451.000000  2.945100e+04
# mean             0.179756      0.317918      2.392279  1.980217e+04
# std              0.383991      0.465675      0.879091  1.901335e+06
# min              0.000000      0.000000      1.000000  3.000000e+00
# 25%              0.000000      0.000000      2.000000  9.000211e+02
# 50%              0.000000      0.000000      2.000000  1.175057e+03
# 75%              0.000000      1.000000      3.000000  1.550688e+03
# max              1.000000      1.000000     20.000000  2.545455e+08
#
#        READY_TO_MOVE        RESALE     LONGITUDE      LATITUDE  \
# count   29451.000000  29451.000000  29451.000000  29451.000000
# mean        0.820244      0.929578     21.300255     76.837695
# std         0.383991      0.255861      6.205306     10.557747
# min         0.000000      0.000000    -37.713008   -121.761248
# ...

# %%
data1=dataset.head(25)

# %%
data1.to_csv("new_data.csv",index=False)

# %%
data2=pd.read_csv("new_data.csv")
data2.head()
# Out:
#   POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0     Owner                   0     0        2       BHK  1300.236407
# 1    Dealer                   0     0        2       BHK  1275.000000
# 2     Owner                   0     0        2       BHK   933.159722
# 3     Owner                   0     1        2       BHK   929.921143
# 4    Dealer                   1     0        2       BHK   999.009247
#
#    READY_TO_MOVE  RESALE       City  LONGITUDE   LATITUDE  \
# 0              1       1  Bangalore  12.969910  77.597960
# 1              1       1     Mysore  12.274538  76.644605
# 2              1       1  Bangalore  12.778033  77.632191
# 3              1       1  Ghaziabad  28.642300  77.344500
# 4              0       1    Kolkata  22.592200  88.484911
#
#    TARGET(PRICE_IN_LACS)
# 0                   55.0
# 1                   51.0
# 2                   43.0
# 3                   62.5
# 4                   60.5

# %%
m=dataset["SQUARE_FT"].mean()

# %%
m
# Out:
# 19802.170190334633

# %%
m=round(m,2)

# %%
m
# Out:
# 19802.17

# %%
dataset["SQUARE_FT"].min()
# Out:
# 3.0

# %%
dataset["SQUARE_FT"].max()
# Out:
# 254545454.5

# %%
data=dataset[["SQUARE_FT","RERA","BHK_NO."]]

# %%
data
# Out:
#          SQUARE_FT  RERA  BHK_NO.
# 0      1300.236407     0        2
# 1      1275.000000     0        2
# 2       933.159722     0        2
# 3       929.921143     1        2
# 4       999.009247     0        2
# ...            ...   ...      ...
# 29446  2500.000000     0        3
# 29447   769.230769     0        2
# 29448  1022.641509     0        2
# 29449   927.079009     0        2
# 29450   896.774194     1        2
#
# [29451 rows x 3 columns]

# %%
dataset.shape
# Out:
# (29451, 12)

# %% [markdown]
# # Working with slicing

# %% [markdown]
# ### Indexed slicing

# %%
data=dataset.iloc[2:8,:4]
data
# Out:
#   POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO.
# 2     Owner                   0     0        2
# 3     Owner                   0     1        2
# 4    Dealer                   1     0        2
# 5     Owner                   0     0        3
# 6    Dealer                   0     0        3
# 7     Owner                   0     1        3

# %%
dataset.iloc[2:4,[1,3]]
# Out:
#    UNDER_CONSTRUCTION  BHK_NO.
# 2                   0        2
# 3                   0        2

# %%
dataset["POSTED_BY"].unique()
# Out:
# array(['Owner', 'Dealer', 'Builder'], dtype=object)

# %%
dataset["POSTED_BY"].nunique()
# Out:
# 3

# %%
dataset["POSTED_BY"].value_counts()
# Out:
# Dealer     18291
# Owner      10538
# Builder      622
# Name: POSTED_BY, dtype: int64

# %% [markdown]
# ### Conditional based slicing

# %%
data=dataset.loc[dataset["POSTED_BY"]=="Owner"]
data.shape
# Out:
# (10538, 12)

# %%
data1=dataset.loc[(dataset["POSTED_BY"]=="Owner")|(dataset["POSTED_BY"]=="Dealer")]
data1.shape
# Out:
# (28829, 12)

# %%
data2=dataset.loc[(dataset["POSTED_BY"]=="Owner")&(dataset["RERA"]==1)]
data2
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 3         Owner                   0     1        2       BHK   929.921143
# 7         Owner                   0     1        3       BHK  1181.012946
# 9         Owner                   0     1        2       BHK   879.120879
# 13        Owner                   0     1        2       BHK  1122.171946
# 57        Owner                   0     1        4       BHK  5200.945626
# ...         ...                 ...   ...      ...       ...          ...
# 29377     Owner                   0     1        2       BHK   953.389831
# 29407     Owner                   0     1        3       BHK  1463.679075
# 29416     Owner                   0     1        1       BHK   550.055005
# 29430     Owner                   0     1        3       BHK  1265.060241
# 29436     Owner                   1     1        2       BHK  1175.132676
#
#        READY_TO_MOVE  RESALE       City  LONGITUDE   LATITUDE  \
# ...

# %% [markdown]
# ### Null check

# %%
dataset.isnull().any()
# Out:
# POSTED_BY                False
# UNDER_CONSTRUCTION       False
# RERA                     False
# BHK_NO.                  False
# BHK_OR_RK                False
# SQUARE_FT                False
# READY_TO_MOVE            False
# RESALE                   False
# City                      True
# LONGITUDE                False
# LATITUDE                 False
# TARGET(PRICE_IN_LACS)    False
# dtype: bool

# %%
dataset.isnull().sum()
# Out:
# POSTED_BY                0
# UNDER_CONSTRUCTION       0
# RERA                     0
# BHK_NO.                  0
# BHK_OR_RK                0
# SQUARE_FT                0
# READY_TO_MOVE            0
# RESALE                   0
# City                     9
# LONGITUDE                0
# LATITUDE                 0
# TARGET(PRICE_IN_LACS)    0
# dtype: int64

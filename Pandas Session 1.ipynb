# %% [markdown]
# ### Pandas Session
# ### Name:- Rahul Patil

# %%
import pandas as pd
import numpy as np

# %%
ab={
    "ID":[1,2,3,4,5],
    "Name":["Ravi","Jitu","Rahul","Deva","Sagar"],
    "City":["Pune","Dhule","jalgaon","Nashik","Mumbai"],
    "salary":[1000,2000,3000,4000,5000]
}
print(ab)
# Out:
# {'ID': [1, 2, 3, 4, 5], 'Name': ['Ravi', 'Jitu', 'Rahul', 'Deva', 'Sagar'], 'City': ['Pune', 'Dhule', 'jalgaon', 'Nashik', 'Mumbai'], 'salary': [1000, 2000, 3000, 4000, 5000]}

# %%
data=pd.DataFrame(ab)
data
# Out:
#    ID   Name     City  salary
# 0   1   Ravi     Pune    1000
# 1   2   Jitu    Dhule    2000
# 2   3  Rahul  jalgaon    3000
# 3   4   Deva   Nashik    4000
# 4   5  Sagar   Mumbai    5000

# %%
data.to_csv("dictionaries.csv",index=False)

# %%
data3=pd.read_csv("dictionaries.csv")
data3
# Out:
#    ID   Name     City  salary
# 0   1   Ravi     Pune    1000
# 1   2   Jitu    Dhule    2000
# 2   3  Rahul  jalgaon    3000
# 3   4   Deva   Nashik    4000
# 4   5  Sagar   Mumbai    5000

# %%
dataset=pd.read_csv(r"C:\Users\Parimal\Downloads\Houseprice_by_City.csv")

# %%
dataset
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                  City  LONGITUDE   LATITUDE  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29451 entries, 0 to 29450
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   POSTED_BY              29451 non-null  object
#  1   UNDER_CONSTRUCTION     29451 non-null  int64
#  2   RERA                   29451 non-null  int64
#  3   BHK_NO.                29451 non-null  int64
#  4   BHK_OR_RK              29451 non-null  object
#  5   SQUARE_FT              29451 non-null  float64
#  6   READY_TO_MOVE          29451 non-null  int64
#  7   RESALE                 29451 non-null  int64
#  8   City                   29442 non-null  object
#  9   LONGITUDE              29451 non-null  float64
#  10  LATITUDE               29451 non-null  float64
#  11  TARGET(PRICE_IN_LACS)  29451 non-null  float64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 2.7+ MB

# %%
dataset.head()
# Out:
#   POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0     Owner                   0     0        2       BHK  1300.236407
# 1    Dealer                   0     0        2       BHK  1275.000000
# 2     Owner                   0     0        2       BHK   933.159722
# 3     Owner                   0     1        2       BHK   929.921143
# 4    Dealer                   1     0        2       BHK   999.009247
#
#    READY_TO_MOVE  RESALE       City  LONGITUDE   LATITUDE  \
# 0              1       1  Bangalore  12.969910  77.597960
# 1              1       1     Mysore  12.274538  76.644605
# 2              1       1  Bangalore  12.778033  77.632191
# 3              1       1  Ghaziabad  28.642300  77.344500
# 4              0       1    Kolkata  22.592200  88.484911
#
#    TARGET(PRICE_IN_LACS)
# 0                   55.0
# 1                   51.0
# 2                   43.0
# 3                   62.5
# 4                   60.5

# %%
dataset.tail()
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                  City  LONGITUDE   LATITUDE  \
# 29446              1       1                  Agra  27.140626  78.043277
# 29447              1       1   Lake View Recidency  39.945409 -86.150721
# 29448              1       1                Jaipur  26.928785  75.828002
# 29449              1       1               Chennai  12.900150  80.227910
# 29450              1       1                Jaipur  26.832353  75.841749
#
#        TARGET(PRICE_IN_LACS)
# 29446                   45.0
# ...

# %%
dataset.describe()
# Out:
#        UNDER_CONSTRUCTION          RERA       BHK_NO.     SQUARE_FT  \
# count        29451.000000  29451.000000  29451.000000  2.945100e+04
# mean             0.179756      0.317918      2.392279  1.980217e+04
# std              0.383991      0.465675      0.879091  1.901335e+06
# min              0.000000      0.000000      1.000000  3.000000e+00
# 25%              0.000000      0.000000      2.000000  9.000211e+02
# 50%              0.000000      0.000000      2.000000  1.175057e+03
# 75%              0.000000      1.000000      3.000000  1.550688e+03
# max              1.000000      1.000000     20.000000  2.545455e+08
#
#        READY_TO_MOVE        RESALE     LONGITUDE      LATITUDE  \
# count   29451.000000  29451.000000  29451.000000  29451.000000
# mean        0.820244      0.929578     21.300255     76.837695
# std         0.383991      0.255861      6.205306     10.557747
# min         0.000000      0.000000    -37.713008   -121.761248
# ...

# %%
data1=dataset.head(10)

# %%
data1.to_csv("home data.csv",index=False)

# %%
data2=pd.read_csv("home data.csv")
data2
# Out:
#   POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0     Owner                   0     0        2       BHK  1300.236407
# 1    Dealer                   0     0        2       BHK  1275.000000
# 2     Owner                   0     0        2       BHK   933.159722
# 3     Owner                   0     1        2       BHK   929.921143
# 4    Dealer                   1     0        2       BHK   999.009247
# 5     Owner                   0     0        3       BHK  1250.000000
# 6    Dealer                   0     0        3       BHK  1495.053957
# 7     Owner                   0     1        3       BHK  1181.012946
# 8    Dealer                   0     1        2       BHK  1040.000000
# 9     Owner                   0     1        2       BHK   879.120879
#
#    READY_TO_MOVE  RESALE       City  LONGITUDE   LATITUDE  \
# 0              1       1  Bangalore  12.969910  77.597960
# 1              1       1     Mysore  12.274538  76.644605
# ...

# %%
d=dataset["SQUARE_FT"].mean()
d
# Out:
# 19802.170190334633

# %%
ab=round(d,2)
ab
# Out:
# 19802.17

# %%
dataset["SQUARE_FT"].min()
# Out:
# 3.0

# %%
dataset["SQUARE_FT"].max()
# Out:
# 254545454.5

# %%
data=dataset[["SQUARE_FT","RERA","BHK_NO."]]
data
# Out:
#          SQUARE_FT  RERA  BHK_NO.
# 0      1300.236407     0        2
# 1      1275.000000     0        2
# 2       933.159722     0        2
# 3       929.921143     1        2
# 4       999.009247     0        2
# ...            ...   ...      ...
# 29446  2500.000000     0        3
# 29447   769.230769     0        2
# 29448  1022.641509     0        2
# 29449   927.079009     0        2
# 29450   896.774194     1        2
#
# [29451 rows x 3 columns]

# %%
dataset.head(10)
# Out:
#   POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0     Owner                   0     0        2       BHK  1300.236407
# 1    Dealer                   0     0        2       BHK  1275.000000
# 2     Owner                   0     0        2       BHK   933.159722
# 3     Owner                   0     1        2       BHK   929.921143
# 4    Dealer                   1     0        2       BHK   999.009247
# 5     Owner                   0     0        3       BHK  1250.000000
# 6    Dealer                   0     0        3       BHK  1495.053957
# 7     Owner                   0     1        3       BHK  1181.012946
# 8    Dealer                   0     1        2       BHK  1040.000000
# 9     Owner                   0     1        2       BHK   879.120879
#
#    READY_TO_MOVE  RESALE       City  LONGITUDE   LATITUDE  \
# 0              1       1  Bangalore  12.969910  77.597960
# 1              1       1     Mysore  12.274538  76.644605
# ...

# %% [markdown]
# ### Working with Slicing

# %%
data=dataset.iloc[5:12,:5]
data
# Out:
#    POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK
# 5      Owner                   0     0        3       BHK
# 6     Dealer                   0     0        3       BHK
# 7      Owner                   0     1        3       BHK
# 8     Dealer                   0     1        2       BHK
# 9      Owner                   0     1        2       BHK
# 10     Owner                   0     0        3       BHK
# 11    Dealer                   0     0        2       BHK

# %%
data1=dataset.iloc[6:12,[1,3,5]]
data1
# Out:
#     UNDER_CONSTRUCTION  BHK_NO.    SQUARE_FT
# 6                    0        3  1495.053957
# 7                    0        3  1181.012946
# 8                    0        2  1040.000000
# 9                    0        2   879.120879
# 10                   0        3  1350.308642
# 11                   0        2  1333.010179

# %%
dataset["BHK_OR_RK"].unique()
# Out:
# array(['BHK', 'RK'], dtype=object)

# %%
dataset["BHK_OR_RK"].nunique()
# Out:
# 2

# %%
dataset["BHK_OR_RK"].value_counts()
# Out:
# BHK    29427
# RK        24
# Name: BHK_OR_RK, dtype: int64

# %% [markdown]
# ### Conditional Slicing

# %%
data=dataset.loc[dataset["City"]=="Bangalore"]
data
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 2         Owner                   0     0        2       BHK   933.159722
# 8        Dealer                   0     1        2       BHK  1040.000000
# 11       Dealer                   0     0        2       BHK  1333.010179
# 12        Owner                   0     0        2       BHK   927.177902
# ...         ...                 ...   ...      ...       ...          ...
# 29408    Dealer                   0     0        2       BHK  1105.845182
# 29415     Owner                   0     0        4       BHK  3650.240584
# 29421    Dealer                   0     0        2       BHK  1409.064497
# 29433     Owner                   0     0        2       BHK  1195.028681
# 29436     Owner                   1     1        2       BHK  1175.132676
#
#        READY_TO_MOVE  RESALE       City  LONGITUDE   LATITUDE  \
# ...

# %%
data.shape
# Out:
# (4319, 12)

# %%
data1=dataset.loc[(dataset["City"]=="Bangalore")|(dataset["City"]=="Ghaziabad")]
data1
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 8        Dealer                   0     1        2       BHK  1040.000000
# 11       Dealer                   0     0        2       BHK  1333.010179
# ...         ...                 ...   ...      ...       ...          ...
# 29408    Dealer                   0     0        2       BHK  1105.845182
# 29415     Owner                   0     0        4       BHK  3650.240584
# 29421    Dealer                   0     0        2       BHK  1409.064497
# 29433     Owner                   0     0        2       BHK  1195.028681
# 29436     Owner                   1     1        2       BHK  1175.132676
#
#        READY_TO_MOVE  RESALE       City  LONGITUDE   LATITUDE  \
# ...

# %%
data1["City"].unique()
# Out:
# array(['Bangalore', 'Ghaziabad'], dtype=object)

# %%
data2=dataset.loc[(dataset["City"]=="Bangalore")&(dataset["BHK_OR_RK"]=="BHK")]
data2
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 2         Owner                   0     0        2       BHK   933.159722
# 8        Dealer                   0     1        2       BHK  1040.000000
# 11       Dealer                   0     0        2       BHK  1333.010179
# 12        Owner                   0     0        2       BHK   927.177902
# ...         ...                 ...   ...      ...       ...          ...
# 29408    Dealer                   0     0        2       BHK  1105.845182
# 29415     Owner                   0     0        4       BHK  3650.240584
# 29421    Dealer                   0     0        2       BHK  1409.064497
# 29433     Owner                   0     0        2       BHK  1195.028681
# 29436     Owner                   1     1        2       BHK  1175.132676
#
#        READY_TO_MOVE  RESALE       City  LONGITUDE   LATITUDE  \
# ...

# %%
data2=dataset.loc[((dataset["City"]=="Bangalore")|(dataset["City"]=="Ghaziabad"))&(dataset["BHK_OR_RK"]=="BHK")]

# %%
data2
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 8        Dealer                   0     1        2       BHK  1040.000000
# 11       Dealer                   0     0        2       BHK  1333.010179
# ...         ...                 ...   ...      ...       ...          ...
# 29408    Dealer                   0     0        2       BHK  1105.845182
# 29415     Owner                   0     0        4       BHK  3650.240584
# 29421    Dealer                   0     0        2       BHK  1409.064497
# 29433     Owner                   0     0        2       BHK  1195.028681
# 29436     Owner                   1     1        2       BHK  1175.132676
#
#        READY_TO_MOVE  RESALE       City  LONGITUDE   LATITUDE  \
# ...

# %%
dataset.isnull().any()
# Out:
# POSTED_BY                False
# UNDER_CONSTRUCTION       False
# RERA                     False
# BHK_NO.                  False
# BHK_OR_RK                False
# SQUARE_FT                False
# READY_TO_MOVE            False
# RESALE                   False
# City                      True
# LONGITUDE                False
# LATITUDE                 False
# TARGET(PRICE_IN_LACS)    False
# dtype: bool

# %%
dataset.isnull().sum()
# Out:
# POSTED_BY                0
# UNDER_CONSTRUCTION       0
# RERA                     0
# BHK_NO.                  0
# BHK_OR_RK                0
# SQUARE_FT                0
# READY_TO_MOVE            0
# RESALE                   0
# City                     9
# LONGITUDE                0
# LATITUDE                 0
# TARGET(PRICE_IN_LACS)    0
# dtype: int64
